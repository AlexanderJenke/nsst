# %%
from hmm_statistics import *

# %%
main("output/tss20_th4_nSt200_nIt101.pkl")
# Out:
# output/tss20_th4_nSt200_nIt101.pkl
# ...
# create test alphabet: 100%|██████████| 11866/11866 [00:00<00:00, 1251310.18it/s]
# Unique vocab per state
# 0 ['im']
# 1 ['einem', 'dem', 'unserem', 'ihrem', 'verschlossenen', 'seinem', 'keinem', 'Santa', 'gutem', 'vollendete', 'nationales', 'ständigem', 'lauter', 'irgendeinem', 'jeglichem', 'Buenos', 'armenischen']
# ...

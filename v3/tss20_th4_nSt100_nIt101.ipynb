# %%
from hmm_statistics import *

# %%
main("output/tss20_th4_nSt100_nIt101.pkl")
# Out:
# output/tss20_th4_nSt100_nIt101.pkl
# ...
# create test alphabet: 100%|██████████| 11866/11866 [00:00<00:00, 1244209.18it/s]
# Unique vocab per state
# 0 ['gestanden', 'beziehungsweise', 'review']
# ...

# %%
from hmm_statistics import *

# %%
main("output/tss20_th4_nSt54_nIt101.pkl")
# Out:
# output/tss20_th4_nSt54_nIt101.pkl
# ...
# create test alphabet: 100%|██████████| 11866/11866 [00:00<00:00, 1195580.17it/s]
# Unique vocab per state
# ...
